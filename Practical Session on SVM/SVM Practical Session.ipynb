# %%
import numpy as np
X = np.array([[-1, -1], [-2, -1], [1, 1], [2, 1]]) #we create 4 examples
y = np.array([-1, -1, 1, 1])
from sklearn.svm import SVC #import de la classe SVC pour SVM
classif=SVC() #we create a SVM with default parameters
classif.fit(X,y) #we learn the model according to given data
res=classif.predict([[-0.8, -1]]) #prediction on a new sample
print(res)
# Out:
# [-1]

# %%
import matplotlib.pyplot as plt #the library for plotting
#we create a mesh to plot in
h = .02 # grid step
x_min= X[:, 0].min() - 1
x_max= X[:, 0].max() + 1
y_min = X[:, 1].min() - 1
y_max = X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
np.arange(y_min, y_max, h))
print(xx)
print(yy)
#the grid is created, the intersections are in xx and yy
# Out:
# [[-3.   -2.98 -2.96 ...,  2.94  2.96  2.98]
#  [-3.   -2.98 -2.96 ...,  2.94  2.96  2.98]
#  [-3.   -2.98 -2.96 ...,  2.94  2.96  2.98]
#  ...,
#  [-3.   -2.98 -2.96 ...,  2.94  2.96  2.98]
#  [-3.   -2.98 -2.96 ...,  2.94  2.96  2.98]
#  [-3.   -2.98 -2.96 ...,  2.94  2.96  2.98]]
# [[-2.   -2.   -2.   ..., -2.   -2.   -2.  ]
#  [-1.98 -1.98 -1.98 ..., -1.98 -1.98 -1.98]
#  [-1.96 -1.96 -1.96 ..., -1.96 -1.96 -1.96]
#  ...,
#  [ 1.94  1.94  1.94 ...,  1.94  1.94  1.94]
#  [ 1.96  1.96  1.96 ...,  1.96  1.96  1.96]
#  [ 1.98  1.98  1.98 ...,  1.98  1.98  1.98]]

# %%
mysvc= SVC(kernel='linear', C = 2.0)
mysvc.fit(X,y)
print(mysvc.score(X,y))
Z2d = mysvc.predict(np.c_[xx.ravel(),yy.ravel()]) # we predict all the grid

Z2d=Z2d.reshape(xx.shape)

plt.figure()
plt.pcolormesh(xx,yy,Z2d, cmap=plt.cm.Paired)
# We plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm)
plt.show()
mysvc.support_vectors_
# Out:
# 1.0
# array([[-1., -1.],
#        [ 1.,  1.]])

# %% [markdown]
# # 2 SVM with Scikit-Learn

# %% [markdown]
# #### Task:1

# %%
#Non Linear Case 
import numpy as np
from sklearn.datasets import make_classification
X12, Y12 = make_classification(n_samples=100 ,n_features=2, n_redundant=0)
plt.scatter(X12[:, 0], X12[:, 1], marker='o', c=Y12,
            s=25, edgecolor='k')
plt.show()

# %% [markdown]
# Generating Points using Make Classification

# %%
SVMC1= SVC()
#print(SVMC1)
SVMC1.fit(X12,Y12)
print(SVMC1.score(X12,Y12))
h = 0.02 # grid step
x_min= X12[:, 0].min() - 1
x_max= X12[:, 0].max() + 1
y_min = X12[:, 1].min() - 1
y_max = X12[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
np.arange(y_min, y_max, h))
Z2 = SVMC1.predict(np.c_[xx.ravel(),yy.ravel()])
Z2=Z2.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx,yy,Z2, cmap=plt.cm.Paired)
# We plot also the training points
plt.scatter(X12[:, 0], X12[:, 1], c=Y12, cmap=plt.cm.coolwarm)
plt.show()
# Out:
# 0.82

# %% [markdown]
# The normal setting of SVM learns the model really good.

# %%
import matplotlib.pyplot as plt #the library for plotting
#we create a mesh to plot in
h = 0.02 # grid step
x_min= X12[:, 0].min() - 1
x_max= X12[:, 0].max() + 1
y_min = X12[:, 1].min() - 1
y_max = X12[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
np.arange(y_min, y_max, h))
SVMC2= SVC(kernel='linear')
SVMC2.fit(X12,Y12)
print(SVMC2.score(X12,Y12))

Z2 = SVMC2.predict(np.c_[xx.ravel(),yy.ravel()])
Z2=Z2.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx,yy,Z2, cmap=plt.cm.Paired)
# We plot also the training points
plt.scatter(X12[:, 0], X12[:, 1], c=Y12, cmap=plt.cm.coolwarm)
plt.show()
# Out:
# 0.79

# %% [markdown]
# When we use linear kernel it is not able to perform well.

# %%
SVMC3= SVC(kernel='rbf', gamma= 0.06)
SVMC3.fit(X12,Y12)
print(SVMC3.score(X12,Y12))
Z2 = SVMC3.predict(np.c_[xx.ravel(),yy.ravel()])
Z2=Z2.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx,yy,Z2, cmap=plt.cm.Paired)
# We plot also the training points
plt.scatter(X12[:, 0], X12[:, 1], c=Y12, cmap=plt.cm.coolwarm)
plt.show()
# Out:
# 0.8

# %%
SVMC3= SVC(kernel='poly', degree=5)
SVMC3.fit(X12,Y12)
print(SVMC3.score(X12,Y12))
Z2 = SVMC3.predict(np.c_[xx.ravel(),yy.ravel()])
Z2=Z2.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx,yy,Z2, cmap=plt.cm.Paired)
# We plot also the training points
plt.scatter(X12[:, 0], X12[:, 1], c=Y12, cmap=plt.cm.coolwarm)
plt.show()
# Out:
# 0.69

# %%
a=[]
m= np.arange(1,15,1)
for i in range(1,15):
    SVMC3= SVC(kernel='poly', degree=i)
    SVMC3.fit(X1,Y1)
    a.append(SVMC3.score(X1,Y1))

# %%
plt.plot(m,a)
g= 'Degree of the Polynomial Kernel'
y= 'Score'
plt.xlabel(g)
plt.ylabel(y)
plt.show()

# %%
import pandas as pd
a1=[]
k=[]
m= np.arange(1,100,1)
for j in range(1,100):
    SVMC3= SVC(kernel='poly', coef0=j)
    SVMC3.fit(X12,Y12)
        #k.append([i,j])
    a1.append(SVMC3.score(X12,Y12))

for i in range(1,100):
    SVMC3= SVC(kernel='poly', C=i)
    SVMC3.fit(X12,Y12)
        #k.append([i,j])
    k.append(SVMC3.score(X12,Y12))
plt.plot(m,a1)
plt.plot(m,k)
plt.legend(['Bias', 'C'], loc= 0)
g1= 'Bias and C value of the Polynomial Kernel'
y11= 'Score'
plt.xlabel(g1)
plt.ylabel(y11)
plt.show()

# %% [markdown]
# The higher the degree the of the polynomial Kernel, the value of score decreases, the SVM performance decreases in this setting. The value of the Bias and C is good for low values in this setting too.

# %%
a=[]
m= np.arange(1,100,1)
for i in range(1,100):
    SVMC3= SVC(kernel='rbf', gamma=i)
    SVMC3.fit(X1,Y1)
    a.append(SVMC3.score(X1,Y1))
    
plt.plot(m,a)
g= 'Gamma value for the RBF Kernel'
y= 'Score'
plt.xlabel(g)
plt.ylabel(y)
plt.show()

# %% [markdown]
# As, value of gamma increases, the performance of the RBF kernel increases the score of SVM.

# %% [markdown]
# # 3. Dataset Generation

# %% [markdown]
# ## 3.1 Random Dataset

# %%
from sklearn.datasets import make_classification
X,y = make_classification(n_samples=50,n_features=2, n_redundant=0, n_informative=2,
random_state=2, n_clusters_per_class=1)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm)
plt.show()

# %% [markdown]
# #### Task1: Tuning the parameters to find the best value of hyperparameter Gamma for RBF Kernel and Polynomial, through Cross-Validation.

# %%
from sklearn.model_selection import cross_val_score
scores=[]
for i in range(1,50):
    score=0
    SVMC4= SVC(kernel= 'rbf', gamma= i)
    a= cross_val_score(SVMC4,X,y, cv=6)
    scores.append(score+(a[0]+a[1]+a[2]))
    
scores.append(score)
print('The best value of Gamma is:', scores.index(max(scores))+1 )
# Out:
# The best value of Gamma is: 9

# %%
from sklearn.model_selection import cross_val_score
scores=[]
for i in range(1,20):
    score=0
    SVMC4= SVC(kernel= 'poly', degree= i)
    a= cross_val_score(SVMC4,X,y,cv=6)
    scores.append(score+(a[0]+a[1]+a[2]))
 
scores.append(score)

print('The best value of Degree is:', scores.index(max(scores))+1 )
# Out:
# The best value of Degree is: 3

# %%
from sklearn.model_selection import cross_val_score
scores=[]
for i in range(1,30):
    score=0
    SVMC4= SVC(kernel= 'poly', coef0= i)
    a= cross_val_score(SVMC4,X,y,cv=6)
    scores.append(score+(a[0]+a[1]+a[2]))
 
scores.append(score)

print('The best value of Bias is:', scores.index(max(scores))+1 )
# Out:
# The best value of Bias is: 2

# %% [markdown]
# #### Task 2: Plotting the decision boundaries and displaying support vectors.

# %% [markdown]
# Plotting for RBF Kernel with best Gamma found in previous task.

# %%
import matplotlib.pyplot as plt #the library for plotting
#we create a mesh to plot in
h = 0.02 # grid step
x_min= X[:, 0].min() - 1
x_max= X[:, 0].max() + 1
y_min = X[:, 1].min() - 1
y_max = X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
np.arange(y_min, y_max, h))
SVMC2= SVC(kernel='rbf', gamma=9)
SVMC2.fit(X,y)
print('Score:',SVMC2.score(X,y))
a= SVMC2.support_vectors_
print('Number of Support Vectors are:', len(a))
Z2 = SVMC2.predict(np.c_[xx.ravel(),yy.ravel()])
Z2=Z2.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx,yy,Z2, cmap=plt.cm.Paired)
# We plot also the training points
plt.scatter(a[:, 0], a[:, 1], cmap=plt.cm.coolwarm)
plt.show()
# Out:
# Score: 0.92
# Number of Support Vectors are: 37

# %% [markdown]
# Plotting the polynomial kernel with best degree and bias found after cross-validation.

# %%
SVMC5= SVC(kernel='poly', degree=3, coef0=2)
SVMC5.fit(X,y)
print('Score:',SVMC5.score(X,y))
a= SVMC5.support_vectors_
print('Number of Support Vectors are:', len(a))
Z2 = SVMC2.predict(np.c_[xx.ravel(),yy.ravel()])
Z2=Z2.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx,yy,Z2, cmap=plt.cm.Paired)
# We plot also the training points
plt.scatter(a[:, 0], a[:, 1], cmap=plt.cm.coolwarm)
plt.show()
# Out:
# Score: 0.92
# Number of Support Vectors are: 14

# %% [markdown]
# ## 3.2 Existing datasets

# %% [markdown]
# #### For Moon Dataset:

# %%
from sklearn.datasets import make_moons
X1, y1 = make_moons(noise = 0.1, random_state=1, n_samples=40)
plt.scatter(X1[:,0],X1[:,1], c = y1, s = 100)
plt.show()

# %%
from sklearn.model_selection import cross_val_score
scores=[]
for i in range(1,50):
    score=0
    SVMC4= SVC(kernel= 'rbf', gamma= i)
    a= cross_val_score(SVMC4,X1,y1, cv=3)
    scores.append(score+(a[0]+a[1]+a[2]))
    
scores.append(score)
print('The best value of Gamma is:', scores.index(max(scores))+1 )


from sklearn.model_selection import cross_val_score
scores=[]
for i in range(1,20):
    score=0
    SVMC8= SVC(kernel= 'poly', degree= i)
    a= cross_val_score(SVMC4,X1,y1,cv=3)
    scores.append(score+(a[0]+a[1]+a[2]))
 
scores.append(score)

print('The best value of Degree is:', scores.index(max(scores))+1 )


from sklearn.model_selection import cross_val_score
scores=[]
for i in range(1,30):
    score=0
    SVMC9= SVC(kernel= 'poly', coef0= i)
    a= cross_val_score(SVMC4,X1,y1,cv=3)
    scores.append(score+(a[0]+a[1]+a[2]))
 
scores.append(score)

print('The best value of Bias is:', scores.index(max(scores))+1 )
# Out:
# The best value of Gamma is: 4
# The best value of Degree is: 1
# The best value of Bias is: 1

# %%
import matplotlib.pyplot as plt #the library for plotting
#we create a mesh to plot in
h = 0.02 # grid step
x_min= X1[:, 0].min() - 1
x_max= X1[:, 0].max() + 1
y_min = X1[:, 1].min() - 1
y_max = X1[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
np.arange(y_min, y_max, h))
SVMC2= SVC(kernel='rbf', gamma=4)
SVMC2.fit(X1,y1)
print('Score:',SVMC2.score(X1,y1))
a= SVMC2.support_vectors_
print('Number of Support Vectors are:', len(a))
Z2 = SVMC2.predict(np.c_[xx.ravel(),yy.ravel()])
Z2=Z2.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx,yy,Z2, cmap=plt.cm.Paired)
# We plot also the training points
plt.scatter(a[:, 0], a[:, 1], cmap=plt.cm.coolwarm)
plt.show()
# Out:
# Score: 1.0
# Number of Support Vectors are: 21

# %%
SVMC2= SVC(kernel='poly', degree=1, coef0=1)
SVMC2.fit(X1,y1)
print('Score:',SVMC2.score(X1,y1))
a= SVMC2.support_vectors_
print('Number of Support Vectors are:', len(a))
Z2 = SVMC2.predict(np.c_[xx.ravel(),yy.ravel()])
Z2=Z2.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx,yy,Z2, cmap=plt.cm.Paired)
# We plot also the training points
plt.scatter(a[:, 0], a[:, 1], cmap=plt.cm.coolwarm)
plt.show()
# Out:
# Score: 0.85
# Number of Support Vectors are: 21

# %% [markdown]
# #### For IRIS dataset

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import load_iris
iris = load_iris()
data1 = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'])

x= data1.iloc[:,2:4]
y=data1.iloc[:,4:5]
y = np.ravel(y)
plt.scatter(x.iloc[:,0],x.iloc[:,1], c=y)
plt.show()

# %%
from sklearn.model_selection import cross_val_score
scores=[]
for i in range(1,50):
    score=0
    SVMC5= SVC(kernel= 'rbf', gamma= i, decision_function_shape= 'ovr')
    a= cross_val_score(SVMC5,x,y, cv=3)
    scores.append(score+(a[0]+a[1]+a[2]))
    
scores.append(score)
print('The best value of Gamma is:', scores.index(max(scores))+1 )

from sklearn.model_selection import cross_val_score
scores=[]
for i in range(1,50):
    score=0
    SVM13= SVC(kernel= 'rbf', C= i, decision_function_shape='ovr')
    a= cross_val_score(SVM13,x,y, cv=3)
    scores.append(score+(a[0]+a[1]+a[2]))
    
scores.append(score)
print('The best value of C is:', scores.index(max(scores))+1 )


from sklearn.model_selection import cross_val_score
scores=[]
for i in range(1,10):
    score=0
    SVMC6= SVC(kernel= 'poly', degree= i, decision_function_shape='ovr')
    a= cross_val_score(SVMC6,x,y,cv=3)
    scores.append(score+(a[0]+a[1]+a[2]))
 
scores.append(score)

print('The best value of Degree is:', scores.index(max(scores))+1 )


from sklearn.model_selection import cross_val_score
scores=[]
for i in range(1,30):
    score=0
    SVMC7= SVC(kernel= 'poly', coef0= i, decision_function_shape='ovr')
    a= cross_val_score(SVMC7,x,y,cv=3)
    scores.append(score+(a[0]+a[1]+a[2]))
 
scores.append(score)

print('The best value of Bias is:', scores.index(max(scores))+1 )
# Out:
# The best value of Gamma is: 1
# The best value of C is: 1
# The best value of Degree is: 7
# The best value of Bias is: 1

# %%
import matplotlib.pyplot as plt #the library for plotting
#we create a mesh to plot in
h = 0.02 # grid step
x_min= x.iloc[:, 0].min() - 1
x_max= x.iloc[:, 0].max() + 1
y_min = x.iloc[:, 1].min() - 1
y_max = x.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
np.arange(y_min, y_max, h))
SVM= SVC(kernel='rbf', gamma=1, C=1)
SVM.fit(x,y)
print('Score:',SVM.score(x,y))
a= SVM.support_vectors_
print('Number of Support Vectors are:', len(a))
Z2 = SVM.predict(np.c_[xx.ravel(),yy.ravel()])
Z2=Z2.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx,yy,Z2, cmap=plt.cm.Paired)
# We plot also the training points
plt.scatter(a[:, 0], a[:, 1], cmap=plt.cm.coolwarm)
plt.show()
# Out:
# Score: 0.966666666667
# Number of Support Vectors are: 30

# %%
SVM= SVC(kernel='poly', degree=7, coef0= 1, C=1)
SVM.fit(x,y)
print('Score:',SVM.score(x,y))
a= SVM.support_vectors_
print('Number of Support Vectors are:', len(a))
Z2 = SVM.predict(np.c_[xx.ravel(),yy.ravel()])
Z2=Z2.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx,yy,Z2, cmap=plt.cm.Paired)
# We plot also the training points
plt.scatter(a[:, 0], a[:, 1], cmap=plt.cm.coolwarm)
plt.show()
# Out:
# Score: 0.966666666667
# Number of Support Vectors are: 13

# %% [markdown]
# # 4 'Real' dataset

# %%
data= pd.read_csv('C:/Users/Rohil/Desktop/New folder (3)/ozone.dat', delimiter=' ')
print(data)
# Out:
#       JOUR  O3obs  MOCAGE  TEMPE    RMH2O     NO2     NO STATION  VentMOD  \
# 0        1     91    93.2   21.5  0.00847   1.602  0.424     Aix   9.5000
# 1        1    100   104.6   20.2  0.00881   2.121  0.531     Aix   8.0100
# 2        0     82   103.6   17.4  0.00951   1.657  0.467     Aix   9.3771
# 3        0     94    94.8   18.8  0.00855   2.350  0.701     Aix   9.4578
# 4        0    107    99.0   23.7  0.00731   1.653  0.452     Aix   7.8791
# 5        0    150   114.3   23.6  0.01182   5.316  1.343     Aix   6.3127
# 6        0    164   127.7   26.6  0.00937   2.841  0.550     Aix   4.8042
# 7        1    135   164.3   23.5  0.01087  15.733  2.911     Aix   4.8795
# 8        1    121   144.1   23.3  0.01168   8.807  1.867     Aix   5.1088
# 9        0    129   112.8   23.7  0.01091  18.911  4.700     Aix   5.4406
# 10       0    118    72.6   22.2  0.01626   4.258  1.304     Aix   5.9641
# 11       0     48   146.0   14.3  0.01453  13.664  2.976     Aix   5.8034
# 12       0     97    87.5   18.5  0.00959   4.126  1.271     Aix   7.5273
# 13       1     83   158.9   15.4  0.01456  10.254  1.839     Aix   2.5942
# 14       1     73   112.6   19.6  0.01220   1.955  0.445     Aix   8.8752
# 15       0     91    76.9   21.7  0.00685   1.382  0.429     Aix  12.3004
# 16       0     70    81.8   24.4  0.00890   1.567  0.443     Aix   9.5000
# 17       0    125   178.6   24.8  0.01206   8.216  1.139     Aix   6.5192
# 18       0    168   127.9   28.2  0.01387   4.632  0.861     Aix   7.1309
# 19       0    113   109.3   26.0  0.01220  12.290  2.958     Aix   5.9816
# 20       1    118   113.0   26.2  0.01064   4.615  0.995     Aix   6.2769
# 21       1    130   136.3   27.2  0.00912   4.276  0.827     Aix   6.0033
# 22       0    179   141.1   27.8  0.01010   7.656  1.750     Aix   5.1313
# 23       0    196   131.4   29.1  0.00919   5.208  1.016     Aix   6.0902
# 24       0    160   141.1   29.5  0.01033   5.043  0.900     Aix   6.1221
# 25       0    180   163.6   29.5  0.00789   8.520  1.385     Aix   5.5227
# 26       0    103   141.6   29.1  0.00663   6.654  1.341     Aix   5.2839
# 27       1    214   159.9   33.2  0.01431   4.122  0.563     Aix   7.2615
# 28       1    178   138.1   30.5  0.01509   6.835  1.174     Aix   6.0877
# 29       0    160   155.1   30.9  0.01526   2.489  0.349     Aix   7.2422
# ...    ...    ...     ...    ...      ...     ...    ...     ...      ...
# 1011     0    111   152.3   21.9  0.01036   4.564  0.744     Pla   7.5060
# 1012     1     73   123.5   18.6  0.00624   4.207  0.937     Pla   8.0000
# 1013     1     78   159.1   16.1  0.00840   2.913  0.442     Pla   6.3820
# 1014     0     83   145.3   19.5  0.00881   0.911  0.151     Pla  17.3658
# 1015     0     73   119.2   21.8  0.00455   0.663  0.139     Pla  16.1276
# 1016     0    115   174.6   20.3  0.00928   3.168  0.441     Pla   5.5362
# 1017     0    100   119.8   19.4  0.00676   0.657  0.130     Pla   6.5000
# 1018     0     89   149.4   22.6  0.00801   5.316  0.801     Pla   7.9310
# 1019     1     70   148.0   18.8  0.00914   4.143  0.529     Pla   3.0017
# 1020     1    104   123.0   18.1  0.01358   0.710  0.131     Pla   2.4739
# 1021     0    122   208.4   21.2  0.01111   3.130  0.344     Pla   3.0265
# 1022     0    119   208.3   22.6  0.01095   2.673  0.284     Pla   3.4785
# 1023     0    110   159.9   22.9  0.00687   1.978  0.298     Pla   4.5277
# 1024     0     94   131.2   20.8  0.00989   0.558  0.093     Pla   5.3759
# 1025     0    104   195.2   23.7  0.00965   1.600  0.184     Pla   3.7590
# 1026     1    100   175.6   23.7  0.00949   1.447  0.180     Pla   4.9031
# 1027     1     90   140.5   22.3  0.00821   0.415  0.062     Pla   4.9820
# 1028     0     89   162.6   19.2  0.00955   1.674  0.203     Pla  16.6652
# 1029     0     77   103.7   17.1  0.01260   0.730  0.153     Pla  16.6760
# 1030     0     68   106.7   16.6  0.01243   0.915  0.165     Pla  17.2308
# 1031     0     65   123.0   16.3  0.01161   0.756  0.160     Pla   3.7947
# 1032     1     77   130.3   17.3  0.01306   0.814  0.124     Pla   5.7706
# 1033     0     74   124.1   17.8  0.00763   6.437  1.321     Pla   7.1063
# 1034     0     80   134.5   16.3  0.01075   1.477  0.239     Pla   3.6056
# 1035     0     93   177.3   20.4  0.00928   5.375  0.684     Pla   5.9908
# 1036     0    116   233.6   22.1  0.01048   4.843  0.431     Pla   4.8052
# 1037     0     60   162.5   15.8  0.00789   3.166  0.411     Pla   2.7203
# 1038     0     74   198.4   16.2  0.00811   8.349  0.942     Pla   4.0311
# 1039     0    121   191.7   16.4  0.00722   2.101  0.199     Pla   3.8000
# 1040     1     93   221.2   16.7  0.00919   2.290  0.202     Pla   2.3022
#
#       VentANG
# 0    -0.64350
# 1    -0.04996
# 2    -0.12832
# 3    -0.34516
# 4    -0.41822
# 5     0.06341
# 6     0.04164
# 7     0.79989
# 8     0.70226
# 9     0.94200
# 10   -0.60661
# 11   -0.03447
# 12    0.33856
# 13    0.48089
# 14   -0.58488
# 15   -0.63537
# 16   -0.64350
# 17    0.72027
# 18    0.38832
# 19    0.66691
# 20    0.53496
# 21    0.52328
# 22    0.57719
# 23    0.51507
# 24    0.66964
# 25    0.55284
# 26    0.51445
# 27    0.39585
# 28    0.73892
# 29   -0.61864
# ...       ...
# 1011 -0.03998
# 1012  0.00000
# 1013 -0.61843
# 1014 -0.85467
# 1015 -0.75909
# 1016  0.35031
# 1017  0.39479
# 1018 -0.40158
# 1019  0.03332
# 1020 -0.24498
# 1021  0.13255
# 1022  1.24905
# 1023  0.53284
# 1024  0.75909
# 1025  0.49935
# 1026  0.20540
# 1027  0.89919
# 1028 -0.32365
# 1029 -0.28571
# 1030 -0.42471
# 1031  0.32175
# 1032 -1.41419
# 1033 -0.68573
# 1034  1.23150
# 1035 -0.58337
# 1036 -0.20964
# 1037 -0.62880
# 1038  0.12435
# 1039  0.00000
# 1040  0.04345
#
# [1041 rows x 10 columns]

# %%
data1= pd.get_dummies(data,'STATION')

# %%
data1['O3obs']= np.where(data1['O3obs'] > 150,1,0)

# %%
m1= data1['O3obs'].as_matrix()
x7= data1.drop('O3obs', axis=1).as_matrix()

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler(copy=True, with_mean= True, with_std= True)
X_normalized = scaler.fit_transform(x7)

# %% [markdown]
# ### Evaluating using the normalized dataset.

# %%
from sklearn.model_selection import cross_val_score
scores=[]
for i in range(1,50):
    score=0
    SVM9= SVC(kernel= 'rbf', gamma= i)
    a= cross_val_score(SVM9,X_normalized,m1)
    scores.append(score+(a[0]+a[1]+a[2]))
    
scores.append(score)
print('The best value of Gamma is:', scores.index(max(scores))+1 )

from sklearn.model_selection import cross_val_score
scores=[]
for i in range(1,50):
    score=0
    SVM13= SVC(kernel= 'rbf', C= i)
    a= cross_val_score(SVM13,X_normalized,m1,cv=5)
    scores.append(score+(a[0]+a[1]+a[2]))
    
scores.append(score)
print('The best value of C is:', scores.index(max(scores))+1 )

from sklearn.model_selection import cross_val_score
scores=[]
for i in range(1,15):
    score=0
    SVM8= SVC(kernel= 'poly', degree= i)
    a= cross_val_score(SVM8,X_normalized,m1,cv=5)
    scores.append(score+(a[0]+a[1]+a[2]))
 
scores.append(score)

print('The best value of Degree is:', scores.index(max(scores))+1 )


from sklearn.model_selection import cross_val_score
scores=[]
for i in range(1,30):
    score=0
    SVM7= SVC(kernel= 'poly', coef0= i)
    a= cross_val_score(SVM7,X_normalized,m1,cv=5)
    scores.append(score+(a[0]+a[1]+a[2]))
 
scores.append(score)

print('The best value of Bias is:', scores.index(max(scores))+1 )
# Out:
# The best value of Gamma is: 2
# The best value of C is: 48
# The best value of Degree is: 5
# The best value of Bias is: 2

# %%
SVM= SVC(kernel='rbf', gamma=5, C=11)
SVM.fit(X_normalized,m1)
print('Score with RBF kernel:',SVM.score(X_normalized,m1))
a= SVM.support_vectors_
print('Number of Support Vectors are:', len(a))
g= SVM.score(X_normalized,m1)
# Out:
# Score with RBF kernel: 1.0
# Number of Support Vectors are: 1040

# %%
SVM= SVC(kernel='poly', degree=3, coef0=2, C=11)
SVM.fit(X_normalized,m1)
print('Score with Polynomial Kernel:',SVM.score(X_normalized,m1))
a= SVM.support_vectors_
print('Number of Support Vectors are:', len(a))
h= SVM.score(X_normalized,m1)
# Out:
# Score with Polynomial Kernel: 0.941402497598
# Number of Support Vectors are: 263

# %%
SVM= SVC(kernel='linear', C=11)
SVM.fit(X_normalized,m1)
print('Score with Linear Kernel:',SVM.score(X_normalized,m1))
a= SVM.support_vectors_
print('Number of Support Vectors are:', len(a))
i= SVM.score(X_normalized,m1)
# Out:
# Score with Linear Kernel: 0.888568683958
# Number of Support Vectors are: 291

# %%
a=['RBF','Polynomial','Linear']
m= [g,h,i]
plt.bar(a, m)
plt.xlabel('The Kernel Used')
plt.ylabel('Performance of the Kernel')
plt.show()

# %% [markdown]
# ### Evaluting using un-normalized dataset.

# %%
from sklearn.model_selection import cross_val_score
scores=[]
for i in range(1,50):
    score=0
    SVM9= SVC(kernel= 'rbf', gamma= i)
    a= cross_val_score(SVM9,x7,m1, cv=5)
    scores.append(score+(a[0]+a[1]+a[2]))
    
scores.append(score)
print('The best value of Gamma is:', scores.index(max(scores))+1 )

from sklearn.model_selection import cross_val_score
scores=[]
for i in range(1,50):
    score=0
    SVM13= SVC(kernel= 'rbf', C= i)
    a= cross_val_score(SVM13,x7,m1, cv=5)
    scores.append(score+(a[0]+a[1]+a[2]))
    
scores.append(score)
print('The best value of C is:', scores.index(max(scores))+1 )
# Out:
# The best value of Gamma is: 1
# The best value of C is: 6

# %%
SVM= SVC(kernel='rbf', gamma=1, C=6)
SVM.fit(X_normalized,m1)
print('Score with RBF kernel:',SVM.score(x7,m1))
a= SVM.support_vectors_
print('Number of Support Vectors are:', len(a))
k= SVM.score(x7,m1)
# Out:
# Score with RBF kernel: 0.829010566763
# Number of Support Vectors are: 775

# %%
SVM= SVC(kernel='linear', C=6)
SVM.fit(X_normalized,m1)
print('Score with Linear Kernel:',SVM.score(x7,m1))
a= SVM.support_vectors_
print('Number of Support Vectors are:', len(a))
l= SVM.score(x7,m1)
# Out:
# Score with Linear Kernel: 0.170989433237
# Number of Support Vectors are: 291

# %% [markdown]
# The polynomial Kernel takes exponential time to learn the best hyperparameters for normal dataset. So it cannot be analysed in normal circumstances.

# %%
q=['RBF','Linear']
r= [k,l]
plt.bar(q, r)
plt.xlabel('The Kernel Used')
plt.ylabel('Performance of the Kernel')
plt.show()

# %% [markdown]
# # Bonus Question

# %%
from sklearn.svm import SVR
clf = SVR(C=1.0, epsilon=0.2, gamma='auto', kernel= 'rbf')
clf.fit(x7,m1)
l=clf.score(x7,m1)
print(l)
# Out:
# 0.684960090435

# %%
clf.fit(X_normalized,m1)
a=clf.score(X_normalized,m1)
print(a)
# Out:
# 0.536282868945

# %%
r=['Normal Data','Normalized Data']
m= [l,a]
plt.bar(r, m)
plt.xlabel('Type of Data Used')
plt.ylabel('Performance')
plt.show()
